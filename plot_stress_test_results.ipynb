# %%
import pandas as pd
df=pd.read_csv("stress_test_result.csv")
df
# Out:
#     n_clients         t   wall_time
# 0          15  0.041727    0.058961
# 1          30  0.038694    0.129831
# 2          45  0.045196    0.315461
# 3          60  0.039404    0.455231
# 4          75  0.106247    0.623202
# ..        ...       ...         ...
# 95       1440  0.373960  285.049576
# 96       1455  1.157147  290.655764
# 97       1470  0.349119  297.139274
# 98       1485  0.837626  305.563885
# 99       1500  0.658810  312.323656
#
# [100 rows x 3 columns]

# %%
df.plot(x="wall_time", y="n_clients", xlabel="wall time (s)", ylabel="n clients", figsize=(10,10))
df.plot(x="n_clients", y="t", xlabel="n_clients", ylabel="mean time taken", figsize=(10,10))
